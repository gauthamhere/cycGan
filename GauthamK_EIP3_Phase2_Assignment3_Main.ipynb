# %% [markdown]
# <a href="https://colab.research.google.com/github/gauthamhere/cycGan/blob/master/GauthamK_EIP3_Phase2_Assignment3_Main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CycleGAN

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import cv2
from google.colab.patches import cv2_imshow

print("Young to old")
print("Domain A - Young , Domain B - Old")
img = cv2.imread("gdrive/My Drive/face4/test_images/ageChange.jpg", cv2.IMREAD_UNCHANGED)
cv2_imshow(img)

print("Previous model's output(Young to old -old) to genderChange(Male to Female)")
print("Domain A - Male , Domain B - Female")

img = cv2.imread("gdrive/My Drive/face4/test_images/age_genderChange.jpg", cv2.IMREAD_UNCHANGED)
cv2_imshow(img)

print("2nd model's output(Young to old+Male to Female) to Race change (White to Black)")
print("Domain A - White , Domain B - Black")

img = cv2.imread("gdrive/My Drive/face4/test_images/age_gender_raceChange.jpg", cv2.IMREAD_UNCHANGED)
cv2_imshow(img)
# Out:
# Young to old
# Domain A - Young , Domain B - Old
# <PIL.Image.Image image mode=RGB size=720x216 at 0x7FD7A4381C18>
# Previous model's output(Young to old -old) to genderChange(Male to Female)
# Domain A - Male , Domain B - Female
# <PIL.Image.Image image mode=RGB size=720x216 at 0x7FD7A4381B38>
# 2nd model's output(Young to old+Male to Female) to Race change (White to Black)
# Domain A - White , Domain B - Black
# <PIL.Image.Image image mode=RGB size=720x216 at 0x7FD7A4381C50>
